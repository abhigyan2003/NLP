# %% [markdown]
# <a href="https://colab.research.google.com/github/abhigyan2003/NLP/blob/main/bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
from textblob import TextBlob

sentence = "Shah Rukh Khan, often hailed as the King of Bollywood, has been an iconic figure in Indian cinema for over three decades. His journey from television actor to one of the most successful and beloved film stars is truly inspirational. Known for his versatility, SRK has played a wide range of characters—from romantic heroes to anti-heroes—winning the hearts of millions worldwide. His performances in films like Dilwale Dulhania Le Jayenge, My Name is Khan, and Chennai Express have become timeless classics, showcasing his exceptional acting skills and emotional depth. Moreover, Shah Rukh Khan's charm and wit during interviews and public appearances make him stand out not just as an actor, but as a personality. Off-screen, he is admired for his humility, philanthropy, and dedication to social causes, including child health and education. His global fan base is a testament to his universal appeal, transcending cultural and geographical boundaries. However, despite his tremendous popularity and achievements, Shah Rukh Khan’s career has not been without criticism. Some film analysts point out that in recent years, he has often chosen roles that feel repetitive or lack the innovation seen in his earlier work. A few of his latest releases failed to make a significant impact at the box office, leading to debates about whether he is struggling to keep up with changing audience tastes. Critics also argue that his acting style can sometimes be overly dramatic, bordering on melodrama, which might not resonate with all viewers. Additionally, there have been rumors about Shah Rukh being difficult to work with during film shoots, although these claims are often speculative and contradicted by those who have collaborated closely with him. In the face of growing competition from younger actors, some feel that SRK needs to reinvent himself to maintain his stature in the industry. While some fans remain loyal and continue to celebrate his legacy, others believe that the Bollywood landscape is evolving and that newer stars are gradually overshadowing the veteran actor. Despite these mixed views, Shah Rukh Khan’s contribution to Indian cinema remains significant, and his influence on aspiring actors and filmmakers is undeniable. His journey, marked by extraordinary highs and some challenges, reflects both the glamour and the complexities of being a superstar in today’s entertainment world."
blob = TextBlob(sentence)

print("Polarity:", blob.sentiment.polarity)        # range: [-1.0, 1.0]
print("Subjectivity:", blob.sentiment.subjectivity)  # range: [0.0, 1.0]
# Out:
# Polarity: 0.08619047619047622
# Subjectivity: 0.4933333333333334

# %%
pip install afinn

# %%
from afinn import Afinn

af = Afinn()
sentence = "Shah Rukh Khan, often hailed as the King of Bollywood, has been an iconic figure in Indian cinema for over three decades. His journey from television actor to one of the most successful and beloved film stars is truly inspirational. Known for his versatility, SRK has played a wide range of characters—from romantic heroes to anti-heroes—winning the hearts of millions worldwide. His performances in films like Dilwale Dulhania Le Jayenge, My Name is Khan, and Chennai Express have become timeless classics, showcasing his exceptional acting skills and emotional depth. Moreover, Shah Rukh Khan's charm and wit during interviews and public appearances make him stand out not just as an actor, but as a personality. Off-screen, he is admired for his humility, philanthropy, and dedication to social causes, including child health and education. His global fan base is a testament to his universal appeal, transcending cultural and geographical boundaries. However, despite his tremendous popularity and achievements, Shah Rukh Khan’s career has not been without criticism. Some film analysts point out that in recent years, he has often chosen roles that feel repetitive or lack the innovation seen in his earlier work. A few of his latest releases failed to make a significant impact at the box office, leading to debates about whether he is struggling to keep up with changing audience tastes. Critics also argue that his acting style can sometimes be overly dramatic, bordering on melodrama, which might not resonate with all viewers. Additionally, there have been rumors about Shah Rukh being difficult to work with during film shoots, although these claims are often speculative and contradicted by those who have collaborated closely with him. In the face of growing competition from younger actors, some feel that SRK needs to reinvent himself to maintain his stature in the industry. While some fans remain loyal and continue to celebrate his legacy, others believe that the Bollywood landscape is evolving and that newer stars are gradually overshadowing the veteran actor. Despite these mixed views, Shah Rukh Khan’s contribution to Indian cinema remains significant, and his influence on aspiring actors and filmmakers is undeniable. His journey, marked by extraordinary highs and some challenges, reflects both the glamour and the complexities of being a superstar in today’s entertainment world."

score = af.score(sentence)
print("AFINN Sentiment Score:", score)
# Out:
# AFINN Sentiment Score: 34.0

# %%
# !pip install nltk

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Create VADER sentiment analyzer object
vader = SentimentIntensityAnalyzer()

# %%
# Test sentence
sentence = "Shah Rukh Khan, often hailed as the King of Bollywood, has been an iconic figure in Indian cinema for over three decades. His journey from television actor to one of the most successful and beloved film stars is truly inspirational. Known for his versatility, SRK has played a wide range of characters—from romantic heroes to anti-heroes—winning the hearts of millions worldwide. His performances in films like Dilwale Dulhania Le Jayenge, My Name is Khan, and Chennai Express have become timeless classics, showcasing his exceptional acting skills and emotional depth. Moreover, Shah Rukh Khan's charm and wit during interviews and public appearances make him stand out not just as an actor, but as a personality. Off-screen, he is admired for his humility, philanthropy, and dedication to social causes, including child health and education. His global fan base is a testament to his universal appeal, transcending cultural and geographical boundaries. However, despite his tremendous popularity and achievements, Shah Rukh Khan’s career has not been without criticism. Some film analysts point out that in recent years, he has often chosen roles that feel repetitive or lack the innovation seen in his earlier work. A few of his latest releases failed to make a significant impact at the box office, leading to debates about whether he is struggling to keep up with changing audience tastes. Critics also argue that his acting style can sometimes be overly dramatic, bordering on melodrama, which might not resonate with all viewers. Additionally, there have been rumors about Shah Rukh being difficult to work with during film shoots, although these claims are often speculative and contradicted by those who have collaborated closely with him. In the face of growing competition from younger actors, some feel that SRK needs to reinvent himself to maintain his stature in the industry. While some fans remain loyal and continue to celebrate his legacy, others believe that the Bollywood landscape is evolving and that newer stars are gradually overshadowing the veteran actor. Despite these mixed views, Shah Rukh Khan’s contribution to Indian cinema remains significant, and his influence on aspiring actors and filmmakers is undeniable. His journey, marked by extraordinary highs and some challenges, reflects both the glamour and the complexities of being a superstar in today’s entertainment."

# Get VADER polarity scores
scores = vader.polarity_scores(sentence)

# Display results
print("VADER Sentiment Scores:")
print(scores)
# Out:
# VADER Sentiment Scores:
# {'neg': 0.074, 'neu': 0.788, 'pos': 0.138, 'compound': 0.9647}

# %%
# !pip install nltk textblob afinn matplotlib
# !python -m textblob.download_corpora
# Out:
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from afinn import Afinn
import matplotlib.pyplot as plt

# Download VADER lexicon
nltk.download('vader_lexicon')

# Initialize analyzers
vader = SentimentIntensityAnalyzer()
afinn = Afinn()

# Sample sentences
sentences = [
    "Shah Rukh Khan is the most charming and talented actor ever!",
    "His movies are boring and predictable.",
    "He’s a superstar, but not all his films are hits.",
    "SRK has a huge fan base across the globe.",
    "Sometimes his acting feels over-the-top and unrealistic."
]

# Store scores for plotting
vader_scores = []
textblob_scores = []
afinn_scores = []

print("\nComparing Sentiment Analysis Models:\n")

for sentence in sentences:
    # VADER
    vader_compound = vader.polarity_scores(sentence)['compound']
    vader_scores.append(vader_compound)

    # TextBlob
    textblob_polarity = TextBlob(sentence).sentiment.polarity
    textblob_scores.append(textblob_polarity)

    # AFINN
    afinn_score = afinn.score(sentence) / 10  # normalize for scale
    afinn_scores.append(afinn_score)

    # Print comparison
    print(f"Sentence: {sentence}")
    print(f"  VADER     Compound: {vader_compound}")
    print(f"  TextBlob  Polarity: {textblob_polarity}")
    print(f"  AFINN     Score   : {afinn_score}")
    print("-" * 60)

# Plotting
x = range(len(sentences))
plt.figure(figsize=(10, 6))
plt.plot(x, vader_scores, label='VADER', marker='o')
plt.plot(x, textblob_scores, label='TextBlob', marker='s')
plt.plot(x, afinn_scores, label='AFINN', marker='^')

plt.xticks(x, [f"S{i+1}" for i in x], rotation=45)
plt.xlabel("Sentences")
plt.ylabel("Sentiment Score")
plt.title("Sentiment Analysis Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Comparing Sentiment Analysis Models:
#
# Sentence: Shah Rukh Khan is the most charming and talented actor ever!
#   VADER     Compound: 0.838
#   TextBlob  Polarity: 0.6916666666666668
#   AFINN     Score   : 0.3
# ------------------------------------------------------------
# Sentence: His movies are boring and predictable.
#   VADER     Compound: -0.3182
#   TextBlob  Polarity: -0.6
#   AFINN     Score   : -0.3
# ------------------------------------------------------------
# Sentence: He’s a superstar, but not all his films are hits.
#   VADER     Compound: 0.0
#   TextBlob  Polarity: 0.0
#   AFINN     Score   : 0.0
# ------------------------------------------------------------
# Sentence: SRK has a huge fan base across the globe.
#   VADER     Compound: 0.5574
#   TextBlob  Polarity: -0.19999999999999998
#   AFINN     Score   : 0.4
# ...

# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_csv('/content/smile-annotations-final.csv', names=['id', 'text', 'category'])
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#                                                                  text category
# id
# 611857364396965889  @aandraous @britishmuseum @AndrewsAntonio Merc...   nocode
# 614484565059596288  Dorian Gray with Rainbow Scarf #LoveWins (from...    happy
# 614746522043973632  @SelectShowcase @Tate_StIves ... Replace with ...    happy
# 614877582664835073  @Sofabsports thank you for following me back. ...    happy
# 611932373039644672  @britishmuseum @TudorHistory What a beautiful ...    happy

# %%
df.category.value_counts()
# Out:
# category
# nocode               1572
# happy                1137
# not-relevant          214
# angry                  57
# surprise               35
# sad                    32
# happy|surprise         11
# happy|sad               9
# disgust|angry           7
# disgust                 6
# sad|disgust             2
# sad|angry               2
# sad|disgust|angry       1
# Name: count, dtype: int64

# %%
df = df[~df.category.str.contains('\|')]

# %%
df = df[df.category != 'nocode']

# %%
df.category.value_counts()
# Out:
# category
# happy           1137
# not-relevant     214
# angry             57
# surprise          35
# sad               32
# disgust            6
# Name: count, dtype: int64

# %%
possible_labels = df.category.unique()

# %%
label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index

# %%
df['label'] = df.category.replace(label_dict)
# Out:
# /tmp/ipython-input-11-2696437164.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['label'] = df.category.replace(label_dict)

# %%
df.head()
# Out:
#                                                                  text  \
# id
# 614484565059596288  Dorian Gray with Rainbow Scarf #LoveWins (from...
# 614746522043973632  @SelectShowcase @Tate_StIves ... Replace with ...
# 614877582664835073  @Sofabsports thank you for following me back. ...
# 611932373039644672  @britishmuseum @TudorHistory What a beautiful ...
# 611570404268883969  @NationalGallery @ThePoldarkian I have always ...
#
#                    category  label
# id
# 614484565059596288    happy      0
# 614746522043973632    happy      0
# 614877582664835073    happy      0
# 611932373039644672    happy      0
# 611570404268883969    happy      0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(df.index.values,
                                                  df.label.values,
                                                  test_size=0.15,
                                                  random_state=17,
                                                  stratify=df.label.values)

# %%
df['data_type'] = ['not_set']*df.shape[0]

# %%
df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
df.groupby(['category', 'label', 'data_type']).count()
# Out:
#                               text
# category     label data_type
# angry        2     train        48
#                    val           9
# disgust      3     train         5
#                    val           1
# happy        0     train       966
#                    val         171
# not-relevant 1     train       182
#                    val          32
# sad          4     train        27
#                    val           5
# surprise     5     train        30
#                    val           5

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',
                                          do_lower_case=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type == 'train'].text.values.tolist(),
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',        # instead of pad_to_max_length=True
    truncation=True,             # truncates longer sequences
    max_length=256,
    return_tensors='pt'
)

encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type == 'val'].text.values.tolist(),
    add_special_tokens=True,
    return_attention_mask=True,
    padding='max_length',        # instead of pad_to_max_length=True
    truncation=True,             # truncates longer sequences
    max_length=256,
    return_tensors='pt'
)

# Labels (unchanged)
input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type == 'train'].label.values)

input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type == 'val'].label.values)

# %%
dataset_train = TensorDataset(input_ids_train, attention_masks_train, labels_train)
dataset_val = TensorDataset(input_ids_val, attention_masks_val, labels_val)

# %%
len(dataset_train)
# Out:
# 1258

# %%
len(dataset_val)
# Out:
# 223

# %%
from transformers import BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
batch_size = 32

dataloader_train = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val,
                                   sampler=SequentialSampler(dataset_val),
                                   batch_size=batch_size)

# %%
from transformers import get_linear_schedule_with_warmup
from torch.optim import AdamW  # <- AdamW now comes from PyTorch

# %%
optimizer = AdamW(model.parameters(),
                  lr=1e-5,
                  eps=1e-8)

# %%
epochs = 5

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %%
import numpy as np

# %%
from sklearn.metrics import f1_score

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

# %%
def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    for label in np.unique(labels_flat):
        y_preds = preds_flat[labels_flat==label]
        y_true = labels_flat[labels_flat==label]
        print(f'Class: {label_dict_inverse[label]}')
        print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %%
import random

seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):

    model.train()

    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        outputs = model(**inputs)

        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


    torch.save(model.state_dict(), f'finetuned_BERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')

    loss_train_avg = loss_train_total/len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg}')

    val_loss, predictions, true_vals = evaluate(dataloader_validation)
    val_f1 = f1_score_func(predictions, true_vals)
    tqdm.write(f'Validation loss: {val_loss}')
    tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
# ...
# Epoch 1:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 1
# Training loss: 0.9678623288869858
# Validation loss: 0.7774264557021004
# F1 Score (Weighted): 0.6656119824269878
# Epoch 2:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 2
# Training loss: 0.6974374189972877
# Validation loss: 0.6516220441886357
# F1 Score (Weighted): 0.6656119824269878
# Epoch 3:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 3
# Training loss: 0.5776941314339638
# Validation loss: 0.6257642252104623
# F1 Score (Weighted): 0.7161711961886958
# Epoch 4:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 4
# Training loss: 0.5089545413851738
# Validation loss: 0.588237247296742
# F1 Score (Weighted): 0.7804944987625279
# Epoch 5:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 5
# Training loss: 0.473403912037611
# Validation loss: 0.5963595807552338
# F1 Score (Weighted): 0.7804944987625279

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
model.load_state_dict(torch.load('finetuned_BERT_epoch_5.model', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class: happy
# Accuracy: 168/171
#
# Class: not-relevant
# Accuracy: 16/32
#
# Class: angry
# Accuracy: 0/9
#
# Class: disgust
# Accuracy: 0/1
#
# Class: sad
# Accuracy: 0/5
#
# Class: surprise
# Accuracy: 0/5

# %%
df['category'].value_counts()
# Out:
# category
# happy           1137
# not-relevant     214
# angry             57
# surprise          35
# sad               32
# disgust            6
# Name: count, dtype: int64

# %%
test_sentences = [
    "I am feeling very sad today.",
    "What a beautiful day it is!",
    "This movie made me really angry.",
    "I don't care about this anymore.",
    "That was so surprising!",
    "Disgusting behavior by the team."
]

for s in test_sentences:
    label, prob = predict_sentiment(s, tokenizer, model, label_dict)
    print(f"Sentence: \"{s}\"\nPredicted Label: {label}, Confidence: {np.max(prob):.3f}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-62-789276959.py in <cell line: 0>()
#       9
#      10 for s in test_sentences:
# ---> 11     label, prob = predict_sentiment(s, tokenizer, model, label_dict)
#      12     print(f"Sentence: \"{s}\"\nPredicted Label: {label}, Confidence: {np.max(prob):.3f}\n")
#
# NameError: name 'predict_sentiment' is not defined

# %%
def predict_sentiment(text, tokenizer, model, label_dict):
    model.eval()

    encoded = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=256,
        return_token_type_ids=False,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt'
    )

    input_id = encoded['input_ids'].to(device)
    attention_mask = encoded['attention_mask'].to(device)

    with torch.no_grad():
        output = model(input_id, attention_mask=attention_mask)

    probs = torch.nn.functional.softmax(output.logits, dim=1)
    predicted_class = torch.argmax(probs, dim=1).item()

    label_dict_inverse = {v: k for k, v in label_dict.items()}
    return label_dict_inverse[predicted_class], probs.cpu().numpy()

# %%
from sklearn.metrics import classification_report

preds_flat = np.argmax(predictions, axis=1).flatten()
labels_flat = true_vals.flatten()
print(classification_report(labels_flat, preds_flat, target_names=label_dict.keys()))
# Out:
#               precision    recall  f1-score   support
#
#        happy       0.86      0.98      0.92       171
# not-relevant       0.57      0.50      0.53        32
#        angry       0.00      0.00      0.00         9
#      disgust       0.00      0.00      0.00         1
#          sad       0.00      0.00      0.00         5
#     surprise       0.00      0.00      0.00         5
#
#     accuracy                           0.83       223
#    macro avg       0.24      0.25      0.24       223
# weighted avg       0.74      0.83      0.78       223
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
