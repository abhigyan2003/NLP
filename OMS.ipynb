# %% [markdown]
# <a href="https://colab.research.google.com/github/abhigyan2003/NLP/blob/main/OMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import threading
import time
from collections import deque
from datetime import datetime


THROTTLE_LIMIT = 100
ACTIVE_HOURS = ("09:00", "17:00")


class RequestType:
    Unknown = 0
    New = 1
    Modify = 2
    Cancel = 3

class ResponseType:
    Unknown = 0
    Accept = 1
    Reject = 2


class OrderRequest:
    def __init__(self, symbolId, price, qty, side, orderId, requestType):
        self.m_symbolId = symbolId
        self.m_price = price
        self.m_qty = qty
        self.m_side = side
        self.m_orderId = orderId
        self.m_requestType = requestType

class OrderResponse:
    def __init__(self, orderId, responseType):
        self.m_orderId = orderId
        self.m_responseType = responseType


class OrderManagement:
    def __init__(self):
        self.queue = deque()
        self.sent_orders = {}
        self.order_metadata = {}
        self.lock = threading.Lock()
        self.last_sent_second = None
        self.orders_sent_this_second = 0
        self.logged_on = False

        self._start_time_monitor()
        self._start_queue_processor()

    def _get_current_ist_time(self):
        return datetime.now()

    def _is_within_trading_window(self):
        now = self._get_current_ist_time().time()
        start_time = datetime.strptime(ACTIVE_HOURS[0], "%H:%M").time()
        end_time = datetime.strptime(ACTIVE_HOURS[1], "%H:%M").time()
        return start_time <= now <= end_time

    def _start_time_monitor(self):
        def monitor():
            while True:
                with self.lock:
                    if self._is_within_trading_window() and not self.logged_on:
                        self.sendLogon()
                        self.logged_on = True
                    elif not self._is_within_trading_window() and self.logged_on:
                        self.sendLogout()
                        self.logged_on = False
                time.sleep(5)
        threading.Thread(target=monitor, daemon=True).start()

    def _start_queue_processor(self):
        def process():
            while True:
                with self.lock:
                    self._process_queue()
                time.sleep(1)
        threading.Thread(target=process, daemon=True).start()

    def _throttle_send(self):
        now = datetime.now()
        if self.last_sent_second != now.second:
            self.last_sent_second = now.second
            self.orders_sent_this_second = 0
        return self.orders_sent_this_second < THROTTLE_LIMIT

    def _process_queue(self):
        while self.queue and self._throttle_send():
            order = self.queue.popleft()
            self._send(order)

    def onData(self, request: OrderRequest):
        with self.lock:
            if not self._is_within_trading_window():
                print(f"Order {request.m_orderId} REJECTED: Outside trading window")
                return

            if request.m_requestType == RequestType.New:
                if self._throttle_send():
                    self._send(request)
                else:
                    self.queue.append(request)

            elif request.m_requestType == RequestType.Modify:
                for queued_order in self.queue:
                    if queued_order.m_orderId == request.m_orderId:
                        queued_order.m_price = request.m_price
                        queued_order.m_qty = request.m_qty
                        print(f"Order {request.m_orderId} MODIFIED in queue")
                        break

            elif request.m_requestType == RequestType.Cancel:
                old_len = len(self.queue)
                self.queue = deque([o for o in self.queue if o.m_orderId != request.m_orderId])
                if len(self.queue) < old_len:
                    print(f"Order {request.m_orderId} CANCELED from queue")

    def _send(self, request: OrderRequest):
        print(f"Sending order {request.m_orderId}")
        self.orders_sent_this_second += 1
        self.sent_orders[request.m_orderId] = request
        self.order_metadata[request.m_orderId] = datetime.now()

    def onDataResponse(self, response: OrderResponse):
        with self.lock:
            sent_time = self.order_metadata.pop(response.m_orderId, None)
            if sent_time:
                latency = (datetime.now() - sent_time).total_seconds() * 1000  # in ms
                self._log_latency(response, latency)
            else:
                print(f"Response received for unknown order {response.m_orderId}")

    def _log_latency(self, response: OrderResponse, latency: float):
        with open("latency_log.txt", "a") as f:
            f.write(f"OrderID: {response.m_orderId}, Response: {response.m_responseType}, Latency: {latency:.2f}ms\n")
        print(f"Logged latency for Order {response.m_orderId}: {latency:.2f} ms")

    def sendLogon(self):
        print("Logon message sent to exchange")

    def sendLogout(self):
        print(" Logout message sent to exchange")




#i used this for just testing the model

if __name__ == "__main__":
    oms = OrderManagement()


    for i in range(105):
        req = OrderRequest(symbolId=1, price=100+i, qty=10+i, side='B', orderId=i, requestType=RequestType.New)
        oms.onData(req)


    modify_req = OrderRequest(symbolId=1, price=999.99, qty=99, side='B', orderId=102, requestType=RequestType.Modify)
    cancel_req = OrderRequest(symbolId=1, price=0, qty=0, side='B', orderId=104, requestType=RequestType.Cancel)
    oms.onData(modify_req)
    oms.onData(cancel_req)


    time.sleep(2)


    for i in range(105):
        response = OrderResponse(orderId=i, responseType=ResponseType.Accept)
        oms.onDataResponse(response)

    print("\nCheck latency_log.txt for logs.")
# Out:
# Order 0 REJECTED: Outside trading window
# Order 1 REJECTED: Outside trading window
# Order 2 REJECTED: Outside trading window
# Order 3 REJECTED: Outside trading window
# Order 4 REJECTED: Outside trading window
# Order 5 REJECTED: Outside trading window
# Order 6 REJECTED: Outside trading window
# Order 7 REJECTED: Outside trading window
# Order 8 REJECTED: Outside trading window
# Order 9 REJECTED: Outside trading window
# Order 10 REJECTED: Outside trading window
# Order 11 REJECTED: Outside trading window
# Order 12 REJECTED: Outside trading window
# Order 13 REJECTED: Outside trading window
# Order 14 REJECTED: Outside trading window
# Order 15 REJECTED: Outside trading window
# Order 16 REJECTED: Outside trading window
# Order 17 REJECTED: Outside trading window
# Order 18 REJECTED: Outside trading window
# Order 19 REJECTED: Outside trading window
# Order 20 REJECTED: Outside trading window
# Order 21 REJECTED: Outside trading window
# Order 22 REJECTED: Outside trading window
# Order 23 REJECTED: Outside trading window
# Order 24 REJECTED: Outside trading window
# Order 25 REJECTED: Outside trading window
# Order 26 REJECTED: Outside trading window
# Order 27 REJECTED: Outside trading window
# Order 28 REJECTED: Outside trading window
# Order 29 REJECTED: Outside trading window
# Order 30 REJECTED: Outside trading window
# Order 31 REJECTED: Outside trading window
# Order 32 REJECTED: Outside trading window
# Order 33 REJECTED: Outside trading window
# Order 34 REJECTED: Outside trading window
# Order 35 REJECTED: Outside trading window
# Order 36 REJECTED: Outside trading window
# Order 37 REJECTED: Outside trading window
# Order 38 REJECTED: Outside trading window
# Order 39 REJECTED: Outside trading window
# Order 40 REJECTED: Outside trading window
# Order 41 REJECTED: Outside trading window
# Order 42 REJECTED: Outside trading window
# Order 43 REJECTED: Outside trading window
# Order 44 REJECTED: Outside trading window
# Order 45 REJECTED: Outside trading window
# Order 46 REJECTED: Outside trading window
# Order 47 REJECTED: Outside trading window
# Order 48 REJECTED: Outside trading window
# Order 49 REJECTED: Outside trading window
# Order 50 REJECTED: Outside trading window
# Order 51 REJECTED: Outside trading window
# Order 52 REJECTED: Outside trading window
# Order 53 REJECTED: Outside trading window
# Order 54 REJECTED: Outside trading window
# Order 55 REJECTED: Outside trading window
# Order 56 REJECTED: Outside trading window
# Order 57 REJECTED: Outside trading window
# Order 58 REJECTED: Outside trading window
# Order 59 REJECTED: Outside trading window
# Order 60 REJECTED: Outside trading window
# Order 61 REJECTED: Outside trading window
# Order 62 REJECTED: Outside trading window
# Order 63 REJECTED: Outside trading window
# Order 64 REJECTED: Outside trading window
# Order 65 REJECTED: Outside trading window
# Order 66 REJECTED: Outside trading window
# Order 67 REJECTED: Outside trading window
# Order 68 REJECTED: Outside trading window
# Order 69 REJECTED: Outside trading window
# Order 70 REJECTED: Outside trading window
# Order 71 REJECTED: Outside trading window
# Order 72 REJECTED: Outside trading window
# Order 73 REJECTED: Outside trading window
# Order 74 REJECTED: Outside trading window
# Order 75 REJECTED: Outside trading window
# Order 76 REJECTED: Outside trading window
# Order 77 REJECTED: Outside trading window
# Order 78 REJECTED: Outside trading window
# Order 79 REJECTED: Outside trading window
# Order 80 REJECTED: Outside trading window
# Order 81 REJECTED: Outside trading window
# Order 82 REJECTED: Outside trading window
# Order 83 REJECTED: Outside trading window
# Order 84 REJECTED: Outside trading window
# Order 85 REJECTED: Outside trading window
# Order 86 REJECTED: Outside trading window
# Order 87 REJECTED: Outside trading window
# Order 88 REJECTED: Outside trading window
# Order 89 REJECTED: Outside trading window
# Order 90 REJECTED: Outside trading window
# Order 91 REJECTED: Outside trading window
# Order 92 REJECTED: Outside trading window
# Order 93 REJECTED: Outside trading window
# Order 94 REJECTED: Outside trading window
# Order 95 REJECTED: Outside trading window
# Order 96 REJECTED: Outside trading window
# Order 97 REJECTED: Outside trading window
# Order 98 REJECTED: Outside trading window
# Order 99 REJECTED: Outside trading window
# Order 100 REJECTED: Outside trading window
# Order 101 REJECTED: Outside trading window
# Order 102 REJECTED: Outside trading window
# Order 103 REJECTED: Outside trading window
# Order 104 REJECTED: Outside trading window
# Order 102 REJECTED: Outside trading window
# Order 104 REJECTED: Outside trading window
# Response received for unknown order 0
# Response received for unknown order 1
# Response received for unknown order 2
# Response received for unknown order 3
# Response received for unknown order 4
# Response received for unknown order 5
# Response received for unknown order 6
# Response received for unknown order 7
# Response received for unknown order 8
# Response received for unknown order 9
# Response received for unknown order 10
# Response received for unknown order 11
# Response received for unknown order 12
# Response received for unknown order 13
# Response received for unknown order 14
# Response received for unknown order 15
# Response received for unknown order 16
# Response received for unknown order 17
# Response received for unknown order 18
# Response received for unknown order 19
# Response received for unknown order 20
# Response received for unknown order 21
# Response received for unknown order 22
# Response received for unknown order 23
# Response received for unknown order 24
# Response received for unknown order 25
# Response received for unknown order 26
# Response received for unknown order 27
# Response received for unknown order 28
# Response received for unknown order 29
# Response received for unknown order 30
# Response received for unknown order 31
# Response received for unknown order 32
# Response received for unknown order 33
# Response received for unknown order 34
# Response received for unknown order 35
# Response received for unknown order 36
# Response received for unknown order 37
# Response received for unknown order 38
# Response received for unknown order 39
# Response received for unknown order 40
# Response received for unknown order 41
# Response received for unknown order 42
# Response received for unknown order 43
# Response received for unknown order 44
# Response received for unknown order 45
# Response received for unknown order 46
# Response received for unknown order 47
# Response received for unknown order 48
# Response received for unknown order 49
# Response received for unknown order 50
# Response received for unknown order 51
# Response received for unknown order 52
# Response received for unknown order 53
# Response received for unknown order 54
# Response received for unknown order 55
# Response received for unknown order 56
# Response received for unknown order 57
# Response received for unknown order 58
# Response received for unknown order 59
# Response received for unknown order 60
# Response received for unknown order 61
# Response received for unknown order 62
# Response received for unknown order 63
# Response received for unknown order 64
# Response received for unknown order 65
# Response received for unknown order 66
# Response received for unknown order 67
# Response received for unknown order 68
# Response received for unknown order 69
# Response received for unknown order 70
# Response received for unknown order 71
# Response received for unknown order 72
# Response received for unknown order 73
# Response received for unknown order 74
# Response received for unknown order 75
# Response received for unknown order 76
# Response received for unknown order 77
# Response received for unknown order 78
# Response received for unknown order 79
# Response received for unknown order 80
# Response received for unknown order 81
# Response received for unknown order 82
# Response received for unknown order 83
# Response received for unknown order 84
# Response received for unknown order 85
# Response received for unknown order 86
# Response received for unknown order 87
# Response received for unknown order 88
# Response received for unknown order 89
# Response received for unknown order 90
# Response received for unknown order 91
# Response received for unknown order 92
# Response received for unknown order 93
# Response received for unknown order 94
# Response received for unknown order 95
# Response received for unknown order 96
# Response received for unknown order 97
# Response received for unknown order 98
# Response received for unknown order 99
# Response received for unknown order 100
# Response received for unknown order 101
# Response received for unknown order 102
# Response received for unknown order 103
# Response received for unknown order 104
#
# Check latency_log.txt for logs.
